# %%
import sys
sys.path.append('..')

import pandas as pd
from utils.plotting_utils import show_power_spectra
# Out:
# Pysteps configuration file found at: /home/gabriele/Documents/fbk/icsc/downscaling-hydra/.venv/lib/python3.10/site-packages/pysteps/pystepsrc

# %%
# Set paths
power_spectra_file_path = '../pretrained_models/outputs/power_spectra_trained_models.pkl'
output_path = '../outputs/'

# %%
# Read in metrics
spectra_df = pd.read_pickle(power_spectra_file_path)
# Plot Figure of power spectra
show_power_spectra(spectra_df, output_dir=output_path)
